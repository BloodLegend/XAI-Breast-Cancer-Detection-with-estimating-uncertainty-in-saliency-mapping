# %%
# ======================================================================================
# CELL 1 — Install, imports, Drive, GPU policy
# ======================================================================================
# !pip install -q scikit-learn matplotlib seaborn opencv-python-headless

import os, math, json, time, random, warnings, re, gc, shutil
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, Model, callbacks, regularizers, optimizers
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input

from sklearn.metrics import (
    confusion_matrix, classification_report,
    roc_auc_score, roc_curve, average_precision_score,
    precision_recall_curve, f1_score, matthews_corrcoef,
    balanced_accuracy_score, accuracy_score, precision_score, recall_score
)

from google.colab import drive
drive.mount("/content/drive")

# VGG19 is safer in float32. Mixed precision can destabilize old VGG-style models.
tf.keras.mixed_precision.set_global_policy("float32")
warnings.filterwarnings("ignore")
tf.get_logger().setLevel("ERROR")

# GPU memory growth.
gpus = tf.config.list_physical_devices("GPU")
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except Exception:
        pass

print("=" * 80)
print("TensorFlow :", tf.__version__)
print("GPU        :", gpus)
print("Policy     :", tf.keras.mixed_precision.global_policy().name)
print("=" * 80)
# Out:
# Mounted at /content/drive
# ================================================================================
# TensorFlow : 2.20.0
# GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Policy     : float32
# ================================================================================

# %%
# ======================================================================================
# CELL 2 — Configuration: edit only this cell if needed
# ======================================================================================
JPEG_BASE  = Path("/content/drive/MyDrive/THESIS/cbis-ddsm/jpeg")
CSV_DIR    = Path("/content/drive/MyDrive/THESIS/cbis-ddsm/csv")
SPLIT_DIR  = Path("/content/drive/MyDrive/THESIS/cbis-ddsm/cropped_split")

TRAIN_DIR = SPLIT_DIR / "train"
VAL_DIR   = SPLIT_DIR / "val"
TEST_DIR  = SPLIT_DIR / "test"

TRAIN_MANIFEST = SPLIT_DIR / "train_manifest.csv"
VAL_MANIFEST   = SPLIT_DIR / "val_manifest.csv"
TEST_MANIFEST  = SPLIT_DIR / "test_manifest.csv"
FULL_MANIFEST  = SPLIT_DIR / "full_manifest.csv"

MODEL_NAME = "VGG19_ULTRA_V6_COMMON_SPLIT_N502_FIXED_XAI"
SAVE_DIR   = Path("/content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

CACHE_DIR = Path("/content/vgg19_common_n502_fixed_xai_cache")
CACHE_DIR.mkdir(parents=True, exist_ok=True)

# Critical anti-regression guardrails. Adjust only if your intentional split is smaller.
EXPECTED_MIN_TRAIN = 1500
EXPECTED_MIN_VAL   = 300
EXPECTED_MIN_TEST  = 300

# Image settings. 256 keeps more lesion detail than 224 while staying T4-safe for VGG19.
IMG_SIZE    = 256
RESIZE_SIZE = 288
CHANNELS    = 3
BATCH_SIZE  = 16      # VGG19 is memory-heavy. Try 24 only on high-RAM GPU.

# Training schedule. Designed to recover performance from full data, not the 530-image subset.
PHASE1_EPOCHS = 16    # frozen backbone, head calibration
PHASE2_EPOCHS = 45    # block5 fine-tune
PHASE3_EPOCHS = 25    # block4 + block5 polish

# Learning rates. VGG19 needs lower LR than DenseNet/Inception/EfficientNet.
PHASE1_LR = 8e-4
PHASE2_LR = 1.2e-5
PHASE3_LR = 2.5e-6
MIN_LR    = 1e-8
WARMUP_FRAC = 0.08

# Regularization.
WEIGHT_DECAY = 8e-5
L2_REG       = 2e-5
DROPOUT_RATE = 0.42
CLIPNORM     = 0.75

# Loss strategy. BCE is the most stable default for VGG19; focal is available.
USE_FOCAL_LOSS  = False
FOCAL_GAMMA     = 2.0
FOCAL_ALPHA      = None    # computed after reading split
LABEL_SMOOTH    = 0.00    # keep 0 for VGG unless it clearly overfits

# Augmentation: deliberately conservative. Too much MixUp/CutMix can hide small lesions.
USE_CLAHE       = True
CLAHE_CLIP      = 2.2
CLAHE_GRID      = (8, 8)

CUTOUT_PROB      = 0.08
CUTOUT_SIZE      = 36
BRIGHTNESS_DELTA = 8.0
CONTRAST_LO      = 0.92
CONTRAST_HI      = 1.08
NOISE_STD_RAW    = 1.25
ROT90_PROB       = 0.25

# Optional batch mixing for Phase 1 only. Default OFF for VGG19 stability.
USE_BATCH_MIXING = False
MIXUP_ALPHA      = 0.20
CUTMIX_ALPHA     = 1.00
MIXUP_PROB       = 0.08
CUTMIX_PROB      = 0.04

# Snapshot / TTA.
TOP_K_SNAPSHOTS = 4
TTA_STEPS       = 8

# Reproducibility.
RANDOM_SEED = 42
os.environ["PYTHONHASHSEED"] = str(RANDOM_SEED)
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

print("=" * 80)
print(f"Model       : {MODEL_NAME}")
print(f"Input       : resize {RESIZE_SIZE} -> crop {IMG_SIZE} x {IMG_SIZE} x {CHANNELS}")
print(f"Batch size  : {BATCH_SIZE}")
print(f"Epochs      : P1={PHASE1_EPOCHS}, P2={PHASE2_EPOCHS}, P3={PHASE3_EPOCHS}")
print(f"LRs         : P1={PHASE1_LR:g}, P2={PHASE2_LR:g}, P3={PHASE3_LR:g}")
print(f"Loss        : {'Focal BCE' if USE_FOCAL_LOSS else 'Weighted BCE'}")
print(f"Augment     : CLAHE={USE_CLAHE}, batch_mix={USE_BATCH_MIXING}, TTA={TTA_STEPS}")
print(f"Save dir    : {SAVE_DIR}")
print("=" * 80)
# Out:
# ================================================================================
# Model       : VGG19_ULTRA_V6_COMMON_SPLIT_N502_FIXED_XAI
# Input       : resize 288 -> crop 256 x 256 x 3
# Batch size  : 16
# Epochs      : P1=16, P2=45, P3=25
# LRs         : P1=0.0008, P2=1.2e-05, P3=2.5e-06
# Loss        : Weighted BCE
# Augment     : CLAHE=True, batch_mix=False, TTA=8
# Save dir    : /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai
# ================================================================================

# %%
# ======================================================================================
# CELL 3 — COMMON FIXED SPLIT DATASET COLLECTION  (n=502) + ROBUST LEAKAGE AUDIT
# ======================================================================================


IMG_EXTS = (".jpg", ".jpeg", ".png")
LABEL2INT = {
    "benign": 0, "BENIGN": 0, "0": 0, 0: 0,
    "malignant": 1, "MALIGNANT": 1, "1": 1, 1: 1,
}
EXPECTED_COMMON_COUNTS = {"train": 2476, "val": 571, "test": 502}

for p in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    assert p.exists(), f"Missing split directory: {p}"

# -----------------------------
# Robust real-patient-ID helpers
# -----------------------------
PATIENT_COL_CANDIDATES = [
    "patient_id", "patient id", "patient", "case_id", "case id", "subject_id", "subject id",
    "Patient ID", "PatientID", "patientID",
]
PATH_COL_CANDIDATES = [
    "path", "filepath", "file_path", "image", "image_path", "filename", "file", "new_filepath",
    "image file path", "cropped image file path", "ROI mask file path",
    "Image File Path", "Cropped Image File Path", "ROI Mask File Path",
]

def _clean_text(x):
    if pd.isna(x):
        return None
    s = str(x).strip()
    if not s or s.lower() in {"nan", "none", "null"}:
        return None
    return s

def normalize_patient_id(x):
    """
    Accept only metadata-like patient IDs. Do NOT accept generic fragments such as
    1-000 / 2-013 because those are often crop/series/coordinate tokens, not patients.
    """
    s = _clean_text(x)
    if s is None:
        return None
    s = s.upper().replace("\\", "/").replace("_", "-")

    # Strong CBIS-DDSM style: P_00001, P-00001, P00001.
    m = re.search(r"\bP[-_ ]?(\d{3,6})\b", s, flags=re.I)
    if m:
        return f"P-{m.group(1).zfill(5)}"

    # Explicit patient/case wording only, not generic numbers.
    m = re.search(r"\b(?:PATIENT|CASE)[-_ ]?(\d{3,8})\b", s, flags=re.I)
    if m:
        return f"PATIENT-{m.group(1).zfill(5)}"

    return None

def strict_patient_id_from_path(path_like):
    """Strict fallback from full path/name. Avoids unsafe generic 1-000 style tokens."""
    s = str(path_like)
    # Prioritize explicit CBIS-DDSM case strings.
    patterns = [
        r"(?i)\b(?:CALC|MASS)[-_](?:TRAINING|TEST)[-_](P[-_ ]?\d{3,6})\b",
        r"(?i)\b(P[-_ ]?\d{3,6})\b",
        r"(?i)\b(?:PATIENT|CASE)[-_ ]?(\d{3,8})\b",
    ]
    for pat in patterns:
        m = re.search(pat, s)
        if m:
            token = m.group(1) if m.lastindex else m.group(0)
            pid = normalize_patient_id(token)
            if pid:
                return pid
    return None

def resolve_manifest_path(p, split):
    s = str(p)
    cand = Path(s)
    if cand.is_absolute() and cand.exists():
        return str(cand)
    checks = [
        SPLIT_DIR / s,
        SPLIT_DIR / split / s,
        SPLIT_DIR / split / "malignant" / Path(s).name,
        SPLIT_DIR / split / "benign" / Path(s).name,
        JPEG_BASE / s,
        JPEG_BASE / Path(s).name,
    ]
    for c in checks:
        if c.exists():
            return str(c)
    return None

def _first_existing_col(df, candidates):
    lower_map = {str(c).strip().lower(): c for c in df.columns}
    for c in candidates:
        if c in df.columns:
            return c
        if str(c).strip().lower() in lower_map:
            return lower_map[str(c).strip().lower()]
    return None

def build_patient_lookup_from_csvs():
    """
    Build lookup dictionaries from split manifests and metadata CSVs.
    Keys include exact path, filename, and stem. Values are verified metadata patient IDs.
    """
    csv_candidates = []
    for p in [TRAIN_MANIFEST, VAL_MANIFEST, TEST_MANIFEST, FULL_MANIFEST]:
        if p.exists():
            csv_candidates.append(p)
    if SPLIT_DIR.exists():
        csv_candidates.extend(sorted(SPLIT_DIR.glob("*.csv")))
    if CSV_DIR.exists():
        csv_candidates.extend(sorted(CSV_DIR.glob("*.csv")))

    # De-duplicate while preserving order.
    seen = set(); csv_candidates_unique = []
    for p in csv_candidates:
        key = str(p.resolve()) if p.exists() else str(p)
        if key not in seen:
            seen.add(key); csv_candidates_unique.append(p)

    lookup = {}
    source_rows = []

    def add_lookup(key, pid, src):
        if key is None or pid is None:
            return
        key = str(key).strip()
        if not key:
            return
        lookup.setdefault(key, pid)
        lookup.setdefault(key.lower(), pid)
        lookup.setdefault(Path(key).name, pid)
        lookup.setdefault(Path(key).name.lower(), pid)
        lookup.setdefault(Path(key).stem, pid)
        lookup.setdefault(Path(key).stem.lower(), pid)
        source_rows.append({"source_csv": str(src), "lookup_key": key, "patient_id": pid})

    for csv_path in csv_candidates_unique:
        try:
            df_meta = pd.read_csv(csv_path)
        except Exception as e:
            print(f"⚠️ Could not read metadata CSV {csv_path}: {e}")
            continue

        pid_col = _first_existing_col(df_meta, PATIENT_COL_CANDIDATES)
        if pid_col is None:
            # Some CBIS columns may not be named patient_id but the paths may contain P_xxxxx.
            pid_col = None

        path_cols = [c for c in df_meta.columns if str(c).strip().lower() in {x.lower() for x in PATH_COL_CANDIDATES}]
        if not path_cols:
            path_cols = [c for c in df_meta.columns if "path" in str(c).lower() or "file" in str(c).lower()]

        # If a metadata patient column exists, use it. Otherwise use strict P_xxxxx in path only.
        for _, row in df_meta.iterrows():
            meta_pid = normalize_patient_id(row[pid_col]) if pid_col is not None else None
            for pc in path_cols:
                raw_path = _clean_text(row.get(pc, None))
                if raw_path is None:
                    continue
                pid = meta_pid or strict_patient_id_from_path(raw_path)
                if pid:
                    add_lookup(raw_path, pid, csv_path)
                    rp = resolve_manifest_path(raw_path, "")
                    if rp:
                        add_lookup(rp, pid, csv_path)

    if source_rows:
        pd.DataFrame(source_rows).drop_duplicates().to_csv(SAVE_DIR / "patient_id_lookup_sources.csv", index=False)
    return lookup

PATIENT_LOOKUP = build_patient_lookup_from_csvs()
print(f"Metadata patient-ID lookup entries: {len(PATIENT_LOOKUP):,}")

def infer_verified_patient_id(path_like):
    """Return (patient_id, source). Source is None if not verified enough for patient leakage audit."""
    p = Path(str(path_like))
    keys = [str(p), str(p).lower(), p.name, p.name.lower(), p.stem, p.stem.lower()]
    for k in keys:
        if k in PATIENT_LOOKUP:
            return PATIENT_LOOKUP[k], "metadata_or_manifest_lookup"
    pid = strict_patient_id_from_path(path_like)
    if pid:
        return pid, "strict_path_pattern"
    return None, None

def collect_from_split_folder(split_name, split_dir):
    rows = []
    for label_name, label_val in [("malignant", 1), ("benign", 0)]:
        folder = split_dir / label_name
        if not folder.exists():
            continue
        for f in sorted(folder.iterdir()):
            if f.suffix.lower() in IMG_EXTS:
                pid, pid_source = infer_verified_patient_id(f)
                rows.append({
                    "path": str(f),
                    "label": int(label_val),
                    "patient_id": pid if pid is not None else f"UNVERIFIED::{f.stem}",
                    "patient_id_verified": bool(pid is not None),
                    "patient_id_source": pid_source if pid_source is not None else "not_available",
                    "split": split_name,
                    "source": "fixed_cropped_split_folder",
                })
    return pd.DataFrame(rows)

def collect_from_manifest(manifest_csv, split):
    """Fallback only if folders are empty."""
    if not manifest_csv.exists():
        return pd.DataFrame(columns=["path", "label", "patient_id", "patient_id_verified", "patient_id_source", "split", "source"])

    df = pd.read_csv(manifest_csv)
    path_col = _first_existing_col(df, PATH_COL_CANDIDATES)
    label_col = _first_existing_col(df, ["label", "class", "target", "pathology", "y", "label_str"])
    pid_col = _first_existing_col(df, PATIENT_COL_CANDIDATES)

    if path_col is None or label_col is None:
        return pd.DataFrame(columns=["path", "label", "patient_id", "patient_id_verified", "patient_id_source", "split", "source"])

    rows = []
    for _, row in df.iterrows():
        p = resolve_manifest_path(row[path_col], split)
        if p is None:
            continue
        lab = row[label_col]
        if isinstance(lab, str):
            lab = lab.strip().lower()
        if lab not in LABEL2INT:
            continue

        pid = normalize_patient_id(row[pid_col]) if pid_col is not None else None
        pid_source = "manifest_patient_column" if pid is not None else None
        if pid is None:
            pid, pid_source = infer_verified_patient_id(p)

        rows.append({
            "path": p,
            "label": int(LABEL2INT[lab]),
            "patient_id": pid if pid is not None else f"UNVERIFIED::{Path(p).stem}",
            "patient_id_verified": bool(pid is not None),
            "patient_id_source": pid_source if pid_source is not None else "not_available",
            "split": split,
            "source": "fixed_cropped_split_manifest_fallback",
        })
    return pd.DataFrame(rows)

def collect_fixed_split(split_name, split_dir, manifest_csv):
    folder_df = collect_from_split_folder(split_name, split_dir)
    folder_df = folder_df.drop_duplicates(subset=["path"]).reset_index(drop=True)
    if len(folder_df) > 0:
        return folder_df
    manifest_df = collect_from_manifest(manifest_csv, split_name)
    manifest_df = manifest_df.drop_duplicates(subset=["path"]).reset_index(drop=True)
    return manifest_df

train_df = collect_fixed_split("train", TRAIN_DIR, TRAIN_MANIFEST)
val_df   = collect_fixed_split("val",   VAL_DIR,   VAL_MANIFEST)
test_df  = collect_fixed_split("test",  TEST_DIR,  TEST_MANIFEST)

all_df = pd.concat([train_df, val_df, test_df], ignore_index=True)
for df in [train_df, val_df, test_df, all_df]:
    df["patient_id"] = df["patient_id"].astype(str).str.upper().str.replace("_", "-", regex=False)
    df["patient_id_verified"] = df["patient_id_verified"].astype(bool)

def split_stats(name, df):
    m = int((df["label"] == 1).sum())
    b = int((df["label"] == 0).sum())
    t = len(df)
    verified = int(df["patient_id_verified"].sum())
    verified_patients = int(df.loc[df["patient_id_verified"], "patient_id"].nunique())
    return name, m, b, t, verified, verified_patients, 100.0 * m / max(t, 1)

print("\nCOMMON FIXED SPLIT DISTRIBUTION")
print(f"{'Split':<8} {'Malignant':>10} {'Benign':>8} {'Total':>7} {'VerifiedID':>10} {'PatientIDs':>10}  Mal%")
print("-" * 82)
for row in [split_stats("train", train_df), split_stats("val", val_df), split_stats("test", test_df)]:
    name, m, b, t, verified, verified_patients, pct = row
    expected = EXPECTED_COMMON_COUNTS.get(name)
    flag = "✓" if expected == t else f"expected {expected}"
    print(f"{name:<8} {m:>10,} {b:>8,} {t:>7,} {verified:>10,} {verified_patients:>10,}  {pct:5.1f}%   {flag}")
print("VerifiedID/PatientIDs are metadata-or-strict-pattern based. Generic filename fragments are ignored.")


if len(test_df) != 502:
    raise RuntimeError(
        f"This COMMON_SPLIT_N502 notebook expects exactly 502 test images, but found {len(test_df):,}. "
        f"Check TEST_DIR={TEST_DIR} and your cropped_split/test folders."
    )
if len(train_df) < EXPECTED_MIN_TRAIN:
    raise RuntimeError(f"Train split too small: {len(train_df):,} < {EXPECTED_MIN_TRAIN:,}")
if len(val_df) < EXPECTED_MIN_VAL:
    raise RuntimeError(f"Validation split too small: {len(val_df):,} < {EXPECTED_MIN_VAL:,}")

# Class weights and focal alpha from the common fixed training split.
n_mal = int((train_df["label"] == 1).sum())
n_ben = int((train_df["label"] == 0).sum())
n_tot = n_mal + n_ben
assert n_mal > 0 and n_ben > 0, "Both classes must exist in train split."

CLASS_WEIGHTS = {
    0: n_tot / (2.0 * n_ben),
    1: n_tot / (2.0 * n_mal),
}
FOCAL_ALPHA = float(np.clip(n_ben / n_tot, 0.45, 0.65))
print(f"\nClass weights -> benign={CLASS_WEIGHTS[0]:.4f}, malignant={CLASS_WEIGHTS[1]:.4f}")
print(f"Focal alpha   -> positive/malignant alpha={FOCAL_ALPHA:.4f}")

# Exact image path leakage must never happen.
def path_overlap(a_name, a_df, b_name, b_df):
    inter = set(a_df["path"]) & set(b_df["path"])
    if inter:
        raise RuntimeError(f"Exact image path leakage {a_name} ↔ {b_name}: {len(inter)} files")
    print(f"✓ No exact path overlap: {a_name} ↔ {b_name}")

def patient_overlap_audit(a_name, a_df, b_name, b_df):
    a_verified = a_df.loc[a_df["patient_id_verified"], "patient_id"]
    b_verified = b_df.loc[b_df["patient_id_verified"], "patient_id"]
    if len(a_verified) == 0 or len(b_verified) == 0:
        print(f"ℹ️ Patient-level audit skipped for {a_name} ↔ {b_name}: verified patient IDs unavailable in one/both splits.")
        return []
    inter = sorted(set(a_verified) & set(b_verified))
    if inter:
        print(f"⚠️ VERIFIED patient/case ID overlap {a_name} ↔ {b_name}: {len(inter)} IDs. Example: {inter[:8]}")
    else:
        print(f"✓ No VERIFIED patient/case ID overlap: {a_name} ↔ {b_name}")
    return inter

print("\nLEAKAGE / CONSISTENCY AUDIT — COMMON FIXED SPLIT")
path_overlap("train", train_df, "val", val_df)
path_overlap("train", train_df, "test", test_df)
path_overlap("val", val_df, "test", test_df)
overlap_tv  = patient_overlap_audit("train", train_df, "val", val_df)
overlap_tt  = patient_overlap_audit("train", train_df, "test", test_df)
overlap_vt  = patient_overlap_audit("val", val_df, "test", test_df)

# Coverage warning: useful for thesis reporting.
coverage_records = []
for name, df in [("train", train_df), ("val", val_df), ("test", test_df)]:
    verified = int(df["patient_id_verified"].sum())
    coverage = verified / max(len(df), 1)
    coverage_records.append({"split": name, "images": len(df), "verified_patient_id_images": verified, "coverage": coverage})
    if coverage < 0.90:
        print(f"ℹ️ Patient-ID audit coverage for {name}: {coverage:.1%}. Exact path audit is valid, but do not claim full patient-level independence from this audit alone.")

# Summary tables for traceability.
patient_summary = (
    all_df.groupby("patient_id")
    .agg(
        n_images=("path", "count"),
        n_malignant=("label", "sum"),
        n_benign=("label", lambda x: int((x == 0).sum())),
        verified=("patient_id_verified", "max"),
        sources=("patient_id_source", lambda x: ",".join(sorted(set(map(str, x))))),
        splits=("split", lambda x: ",".join(sorted(set(map(str, x))))),
    )
    .reset_index()
)
split_summary_df = pd.DataFrame(
    [split_stats("train", train_df), split_stats("val", val_df), split_stats("test", test_df)],
    columns=["split", "malignant", "benign", "total", "verified_id_images", "verified_patient_ids", "malignant_percent"]
)
patient_audit_df = pd.DataFrame(coverage_records)
patient_overlap_df = pd.DataFrame({
    "pair": ["train-val", "train-test", "val-test"],
    "n_verified_overlaps": [len(overlap_tv), len(overlap_tt), len(overlap_vt)],
    "overlap_ids_preview": ["|".join(overlap_tv[:25]), "|".join(overlap_tt[:25]), "|".join(overlap_vt[:25])],
})

# Persist split inventory and config.
train_df.to_csv(SAVE_DIR / "train_inventory_common_n502.csv", index=False)
val_df.to_csv(SAVE_DIR / "val_inventory_common_n502.csv", index=False)
test_df.to_csv(SAVE_DIR / "test_inventory_common_n502.csv", index=False)
all_df.to_csv(SAVE_DIR / "all_inventory_common_n502.csv", index=False)
patient_summary.to_csv(SAVE_DIR / "patient_group_summary_common_n502.csv", index=False)
split_summary_df.to_csv(SAVE_DIR / "split_summary_common_n502.csv", index=False)
patient_audit_df.to_csv(SAVE_DIR / "patient_id_audit_coverage.csv", index=False)
patient_overlap_df.to_csv(SAVE_DIR / "patient_id_overlap_audit.csv", index=False)

# Also save generic names so downstream cells and external analysis stay simple.
train_df.to_csv(SAVE_DIR / "train_inventory.csv", index=False)
val_df.to_csv(SAVE_DIR / "val_inventory.csv", index=False)
test_df.to_csv(SAVE_DIR / "test_inventory.csv", index=False)

config = {
    "MODEL_NAME": MODEL_NAME,
    "SPLIT_MODE": "fixed_common_cropped_split_n502_with_robust_metadata_patient_audit",
    "SPLIT_DIR": str(SPLIT_DIR),
    "SAVE_DIR": str(SAVE_DIR),
    "EXPECTED_COMMON_COUNTS": EXPECTED_COMMON_COUNTS,
    "IMG_SIZE": IMG_SIZE,
    "RESIZE_SIZE": RESIZE_SIZE,
    "BATCH_SIZE": BATCH_SIZE,
    "PHASE1_EPOCHS": PHASE1_EPOCHS,
    "PHASE2_EPOCHS": PHASE2_EPOCHS,
    "PHASE3_EPOCHS": PHASE3_EPOCHS,
    "USE_FOCAL_LOSS": USE_FOCAL_LOSS,
    "USE_BATCH_MIXING": USE_BATCH_MIXING,
    "CLASS_WEIGHTS": CLASS_WEIGHTS,
    "FOCAL_ALPHA": FOCAL_ALPHA,
    "total_count": len(all_df),
    "train_count": len(train_df),
    "val_count": len(val_df),
    "test_count": len(test_df),
    "patient_id_lookup_entries": len(PATIENT_LOOKUP),
    "train_verified_patient_id_images": int(train_df["patient_id_verified"].sum()),
    "val_verified_patient_id_images": int(val_df["patient_id_verified"].sum()),
    "test_verified_patient_id_images": int(test_df["patient_id_verified"].sum()),
    "train_verified_patient_ids": int(train_df.loc[train_df["patient_id_verified"], "patient_id"].nunique()),
    "val_verified_patient_ids": int(val_df.loc[val_df["patient_id_verified"], "patient_id"].nunique()),
    "test_verified_patient_ids": int(test_df.loc[test_df["patient_id_verified"], "patient_id"].nunique()),
}
with open(SAVE_DIR / "run_config.json", "w") as f:
    json.dump(config, f, indent=2)

print(f"Artifacts will be saved to: {SAVE_DIR}")
# Out:
# Metadata patient-ID lookup entries: 72,788
#
# COMMON FIXED SPLIT DISTRIBUTION
# Split     Malignant   Benign   Total VerifiedID PatientIDs  Mal%
# ----------------------------------------------------------------------------------
# train         1,004    1,472   2,476      2,476      1,096   40.5%   ✓
# val             231      340     571        571        235   40.5%   ✓
# test            215      287     502        502        235   42.8%   ✓
# VerifiedID/PatientIDs are metadata-or-strict-pattern based. Generic filename fragments are ignored.
#
# Class weights -> benign=0.8410, malignant=1.2331
# Focal alpha   -> positive/malignant alpha=0.5945
#
# LEAKAGE / CONSISTENCY AUDIT — COMMON FIXED SPLIT
# ✓ No exact path overlap: train ↔ val
# ✓ No exact path overlap: train ↔ test
# ✓ No exact path overlap: val ↔ test
# ✓ No VERIFIED patient/case ID overlap: train ↔ val
# ✓ No VERIFIED patient/case ID overlap: train ↔ test
# ✓ No VERIFIED patient/case ID overlap: val ↔ test
# Artifacts will be saved to: /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai

# %%
# ======================================================================================
# CELL 4 — Preprocessing, augmentation, tf.data pipelines
# ======================================================================================
AUTO = tf.data.AUTOTUNE

def clahe_np(img_uint8):
    """CLAHE on LAB L-channel. Input/output RGB uint8."""
    img = np.ascontiguousarray(img_uint8, dtype=np.uint8)
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=CLAHE_CLIP, tileGridSize=CLAHE_GRID)
    l_eq = clahe.apply(l)
    return cv2.cvtColor(cv2.merge([l_eq, a, b]), cv2.COLOR_LAB2RGB).astype(np.uint8)

def static_load(path, label):
    """Decode -> resize -> optional CLAHE. Cached before random augmentation."""
    raw = tf.io.read_file(path)
    img = tf.io.decode_image(raw, channels=CHANNELS, expand_animations=False)
    img.set_shape([None, None, CHANNELS])
    img = tf.image.resize(img, [RESIZE_SIZE, RESIZE_SIZE], method="bicubic", antialias=True)
    img = tf.cast(tf.clip_by_value(img, 0.0, 255.0), tf.uint8)
    if USE_CLAHE:
        img = tf.numpy_function(clahe_np, [img], tf.uint8)
        img.set_shape([RESIZE_SIZE, RESIZE_SIZE, CHANNELS])
    return img, tf.cast(label, tf.float32)

def center_crop(img):
    off = (RESIZE_SIZE - IMG_SIZE) // 2
    img = img[off:off + IMG_SIZE, off:off + IMG_SIZE, :]
    img.set_shape([IMG_SIZE, IMG_SIZE, CHANNELS])
    return img

def random_cutout_raw(img, size=CUTOUT_SIZE):
    """Cutout on raw [0,255] image. Fill with image mean, not black."""
    h = tf.shape(img)[0]
    w = tf.shape(img)[1]
    cy = tf.random.uniform([], 0, h, dtype=tf.int32)
    cx = tf.random.uniform([], 0, w, dtype=tf.int32)
    half = size // 2
    y1 = tf.maximum(0, cy - half)
    y2 = tf.minimum(h, cy + half)
    x1 = tf.maximum(0, cx - half)
    x2 = tf.minimum(w, cx + half)
    yy = tf.range(h)[:, None]
    xx = tf.range(w)[None, :]
    mask = tf.cast((yy >= y1) & (yy < y2) & (xx >= x1) & (xx < x2), tf.float32)[..., None]
    fill = tf.reduce_mean(img, axis=[0, 1], keepdims=True)
    return img * (1.0 - mask) + fill * mask

def augment_train(img_uint8, label):
    """Conservative raw-space augmentation -> VGG19 caffe preprocess_input."""
    img = tf.cast(img_uint8, tf.float32)
    img = tf.image.random_crop(img, [IMG_SIZE, IMG_SIZE, CHANNELS])
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)

    do_rot = tf.random.uniform([]) < ROT90_PROB
    img = tf.cond(
        do_rot,
        lambda: tf.image.rot90(img, tf.random.uniform([], 1, 4, dtype=tf.int32)),
        lambda: img,
    )

    img = tf.image.random_brightness(img, max_delta=BRIGHTNESS_DELTA)
    img = tf.image.random_contrast(img, lower=CONTRAST_LO, upper=CONTRAST_HI)
    if NOISE_STD_RAW > 0:
        img = img + tf.random.normal(tf.shape(img), mean=0.0, stddev=NOISE_STD_RAW)
    img = tf.clip_by_value(img, 0.0, 255.0)

    do_cut = tf.random.uniform([]) < CUTOUT_PROB
    img = tf.cond(do_cut, lambda: random_cutout_raw(img), lambda: img)
    img = preprocess_input(img)  # RGB -> BGR, ImageNet mean subtraction for VGG19
    return img, tf.cast(label, tf.float32)

def preprocess_eval(img_uint8, label):
    img = tf.cast(center_crop(img_uint8), tf.float32)
    img = preprocess_input(img)
    return img, tf.cast(label, tf.float32)

def preprocess_tta(img_uint8, label, tta_id):
    img = tf.cast(center_crop(img_uint8), tf.float32)
    tta_id = tf.cast(tta_id, tf.int32)
    img = tf.case([
        (tf.equal(tta_id, 1), lambda: tf.image.flip_left_right(img)),
        (tf.equal(tta_id, 2), lambda: tf.image.flip_up_down(img)),
        (tf.equal(tta_id, 3), lambda: tf.image.flip_up_down(tf.image.flip_left_right(img))),
        (tf.equal(tta_id, 4), lambda: tf.image.rot90(img, k=1)),
        (tf.equal(tta_id, 5), lambda: tf.image.rot90(img, k=2)),
        (tf.equal(tta_id, 6), lambda: tf.image.rot90(img, k=3)),
        (tf.equal(tta_id, 7), lambda: tf.image.rot90(tf.image.flip_left_right(img), k=1)),
    ], default=lambda: img, exclusive=True)
    img = preprocess_input(img)
    return img, tf.cast(label, tf.float32)

def sample_beta(alpha):
    g1 = tf.random.gamma([], alpha)
    g2 = tf.random.gamma([], alpha)
    return g1 / (g1 + g2 + 1e-8)

def mixup(images, labels, alpha=MIXUP_ALPHA):
    bs = tf.shape(images)[0]
    lam = sample_beta(alpha)
    lam = tf.maximum(lam, 1.0 - lam)
    idx = tf.random.shuffle(tf.range(bs))
    images2 = tf.gather(images, idx)
    labels2 = tf.gather(labels, idx)
    return lam * images + (1.0 - lam) * images2, lam * labels + (1.0 - lam) * labels2

def cutmix(images, labels, alpha=CUTMIX_ALPHA):
    bs = tf.shape(images)[0]
    h = tf.shape(images)[1]
    w = tf.shape(images)[2]
    lam = sample_beta(alpha)
    cut_ratio = tf.sqrt(1.0 - lam)
    cut_h = tf.cast(tf.cast(h, tf.float32) * cut_ratio, tf.int32)
    cut_w = tf.cast(tf.cast(w, tf.float32) * cut_ratio, tf.int32)
    cy = tf.random.uniform([], 0, h, dtype=tf.int32)
    cx = tf.random.uniform([], 0, w, dtype=tf.int32)
    y1 = tf.maximum(0, cy - cut_h // 2)
    y2 = tf.minimum(h, cy + cut_h // 2)
    x1 = tf.maximum(0, cx - cut_w // 2)
    x2 = tf.minimum(w, cx + cut_w // 2)
    yy = tf.range(h)[:, None]
    xx = tf.range(w)[None, :]
    mask = tf.cast((yy >= y1) & (yy < y2) & (xx >= x1) & (xx < x2), images.dtype)[None, ..., None]
    idx = tf.random.shuffle(tf.range(bs))
    images2 = tf.gather(images, idx)
    labels2 = tf.gather(labels, idx)
    mixed = images * (1.0 - mask) + images2 * mask
    area = tf.cast((y2 - y1) * (x2 - x1), tf.float32)
    lam_actual = 1.0 - area / tf.cast(h * w, tf.float32)
    return mixed, tf.cast(lam_actual, labels.dtype) * labels + (1.0 - tf.cast(lam_actual, labels.dtype)) * labels2

def mix_or_keep(images, labels):
    if not USE_BATCH_MIXING:
        return images, labels
    r = tf.random.uniform([])
    return tf.case([
        (r < MIXUP_PROB, lambda: mixup(images, labels)),
        (r < MIXUP_PROB + CUTMIX_PROB, lambda: cutmix(images, labels)),
    ], default=lambda: (images, labels), exclusive=True)

def build_static_ds(df, split_name):
    paths = tf.constant(df["path"].astype(str).values)
    labels = tf.constant(df["label"].astype(np.int32).values, dtype=tf.int32)
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.map(static_load, num_parallel_calls=AUTO)
    # Disk cache prevents expensive CLAHE repeat work without relying on RAM.
    return ds.cache(str(CACHE_DIR / f"{split_name}_static.cache"))

train_static = build_static_ds(train_df, "train")
val_static   = build_static_ds(val_df,   "val")
test_static  = build_static_ds(test_df,  "test")

def make_train_ds(use_mix=False):
    ds = train_static.shuffle(len(train_df), seed=RANDOM_SEED, reshuffle_each_iteration=True)
    ds = ds.map(augment_train, num_parallel_calls=AUTO)
    ds = ds.batch(BATCH_SIZE, drop_remainder=False)
    if use_mix:
        ds = ds.map(mix_or_keep, num_parallel_calls=AUTO)
    return ds.prefetch(AUTO)

def make_eval_ds(static_ds):
    return static_ds.map(preprocess_eval, num_parallel_calls=AUTO).batch(BATCH_SIZE).prefetch(AUTO)

def make_tta_ds(static_ds, tta_id):
    return static_ds.map(lambda x, y: preprocess_tta(x, y, tta_id), num_parallel_calls=AUTO).batch(BATCH_SIZE).prefetch(AUTO)

train_ds_mix   = make_train_ds(use_mix=USE_BATCH_MIXING)
train_ds_clean = make_train_ds(use_mix=False)
val_ds         = make_eval_ds(val_static)
test_ds        = make_eval_ds(test_static)
steps_per_epoch = math.ceil(len(train_df) / BATCH_SIZE)

print(f"Train images: {len(train_df):,} | Val: {len(val_df):,} | Test: {len(test_df):,}")
print(f"Steps/epoch : {steps_per_epoch:,}")
assert steps_per_epoch >= 80, "Too few training steps. Dataset collection is still wrong."
# Out:
# Train images: 2,476 | Val: 571 | Test: 502
# Steps/epoch : 155

# %%
# ======================================================================================
# CELL 5 — Augmentation sanity check
# ======================================================================================
def deprocess_vgg(x):
    """Convert VGG-preprocessed BGR tensor back to displayable RGB uint8."""
    arr = x.numpy().copy()
    arr[..., 0] += 103.939
    arr[..., 1] += 116.779
    arr[..., 2] += 123.680
    arr = arr[..., ::-1]
    return np.clip(arr, 0, 255).astype(np.uint8)

batch_x, batch_y = next(iter(train_ds_mix if USE_BATCH_MIXING else train_ds_clean))
print("Batch shape :", batch_x.shape)
print("Image range :", float(tf.reduce_min(batch_x)), "to", float(tf.reduce_max(batch_x)))
print("Label range :", float(tf.reduce_min(batch_y)), "to", float(tf.reduce_max(batch_y)))

assert batch_x.shape[1:] == (IMG_SIZE, IMG_SIZE, CHANNELS), "Image shape mismatch."
assert float(tf.reduce_max(batch_x)) > 50 or float(tf.reduce_min(batch_x)) < -50, "VGG preprocess range looks wrong."

fig, axes = plt.subplots(2, 6, figsize=(18, 6))
for i, ax in enumerate(axes.flat):
    if i < batch_x.shape[0]:
        ax.imshow(deprocess_vgg(batch_x[i]))
        ax.set_title(f"y={float(batch_y[i]):.2f}", fontsize=9)
    ax.axis("off")
plt.suptitle("VGG19 V5 augmented training batch", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(SAVE_DIR / "augmentation_sanity.png", dpi=140, bbox_inches="tight")
plt.show()
# Out:
# Batch shape : (16, 256, 256, 3)
# Image range : -123.68000030517578 to 151.06100463867188
# Label range : 0.0 to 1.0

# %%
# ======================================================================================
# CELL 6 — Build VGG19 with a VGG-safe dual-pooling head
# ======================================================================================
def se_block(feat, ratio=8, name="se"):
    channels = int(feat.shape[-1])
    x = layers.GlobalAveragePooling2D(name=f"{name}_gap")(feat)
    x = layers.Dense(max(channels // ratio, 32), activation="relu", kernel_initializer="he_normal", name=f"{name}_fc1")(x)
    x = layers.Dense(channels, activation="sigmoid", kernel_initializer="glorot_uniform", name=f"{name}_fc2")(x)
    x = layers.Reshape((1, 1, channels), name=f"{name}_reshape")(x)
    return layers.Multiply(name=f"{name}_scale")([feat, x])

def build_vgg19_v5():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, CHANNELS), name="input")
    base = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    base.trainable = False

    feat = base.output
    feat = se_block(feat, ratio=8, name="se_block5")
    feat = layers.SpatialDropout2D(0.08, name="spatial_drop")(feat)

    gap = layers.GlobalAveragePooling2D(name="gap")(feat)
    gmp = layers.GlobalMaxPooling2D(name="gmp")(feat)
    x = layers.Concatenate(name="pool_concat")([gap, gmp])

    x = layers.BatchNormalization(name="head_bn0")(x)
    x = layers.Dropout(DROPOUT_RATE, name="head_drop0")(x)

    x = layers.Dense(512, use_bias=False, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(L2_REG), name="head_fc1")(x)
    x = layers.BatchNormalization(name="head_bn1")(x)
    x = layers.Activation("swish", name="head_swish1")(x)
    x = layers.Dropout(0.32, name="head_drop1")(x)

    x = layers.Dense(192, use_bias=False, kernel_initializer="he_normal", kernel_regularizer=regularizers.l2(L2_REG), name="head_fc2")(x)
    x = layers.BatchNormalization(name="head_bn2")(x)
    x = layers.Activation("swish", name="head_swish2")(x)
    x = layers.Dropout(0.22, name="head_drop2")(x)

    outputs = layers.Dense(1, activation="sigmoid", dtype="float32", name="output")(x)
    model = Model(inputs, outputs, name=MODEL_NAME)
    return model, base

model, base = build_vgg19_v5()
HEAD_LAYER_PREFIXES = ("se_block5", "spatial_drop", "gap", "gmp", "pool_concat", "head_", "output")

print(f"Total params     : {model.count_params():,}")
print(f"Trainable params : {sum(tf.size(w).numpy() for w in model.trainable_weights):,}")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Total params     : 20,720,193
# Trainable params : 692,353
# Model: "VGG19_ULTRA_V6_COMMON_SPLIT_N502_FIXED_XAI"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 256, 256,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 256, 256,  │      1,792 │ input[0][0]       │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 256, 256,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 128, 128,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 128, 128,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 128, 128,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 64, 64,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 64, 64,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 64, 64,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 64, 64,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv4        │ (None, 64, 64,    │    590,080 │ block3_conv3[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 32, 32,    │          0 │ block3_conv4[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 32, 32,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 32, 32,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 32, 32,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv4        │ (None, 32, 32,    │  2,359,808 │ block4_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 16, 16,    │          0 │ block4_conv4[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 16, 16,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 16, 16,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 16, 16,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv4        │ (None, 16, 16,    │  2,359,808 │ block5_conv3[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 8, 8, 512) │          0 │ block5_conv4[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block5_gap       │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block5_fc1       │ (None, 64)        │     32,832 │ se_block5_gap[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block5_fc2       │ (None, 512)       │     33,280 │ se_block5_fc1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block5_reshape   │ (None, 1, 1, 512) │          0 │ se_block5_fc2[0]… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ se_block5_scale     │ (None, 8, 8, 512) │          0 │ block5_pool[0][0… │
# │ (Multiply)          │                   │            │ se_block5_reshap… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_drop        │ (None, 8, 8, 512) │          0 │ se_block5_scale[… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ spatial_drop[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gmp                 │ (None, 512)       │          0 │ spatial_drop[0][… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_concat         │ (None, 1024)      │          0 │ gap[0][0],        │
# │ (Concatenate)       │                   │            │ gmp[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_bn0            │ (None, 1024)      │      4,096 │ pool_concat[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_drop0          │ (None, 1024)      │          0 │ head_bn0[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_fc1 (Dense)    │ (None, 512)       │    524,288 │ head_drop0[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_bn1            │ (None, 512)       │      2,048 │ head_fc1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_swish1         │ (None, 512)       │          0 │ head_bn1[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_drop1          │ (None, 512)       │          0 │ head_swish1[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_fc2 (Dense)    │ (None, 192)       │     98,304 │ head_drop1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_bn2            │ (None, 192)       │        768 │ head_fc2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_swish2         │ (None, 192)       │          0 │ head_bn2[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_drop2          │ (None, 192)       │          0 │ head_swish2[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │        193 │ head_drop2[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,720,193 (79.04 MB)
#  Trainable params: 692,353 (2.64 MB)
#  Non-trainable params: 20,027,840 (76.40 MB)

# %%
# ======================================================================================
# CELL 7 — Loss, LR schedule, callbacks, checkpoint utilities
# ======================================================================================
def weighted_bce_loss(label_smoothing=LABEL_SMOOTH):
    """Weighted BCE using CLASS_WEIGHTS. More stable for VGG19 than aggressive focal by default."""
    w0 = tf.constant(CLASS_WEIGHTS[0], tf.float32)
    w1 = tf.constant(CLASS_WEIGHTS[1], tf.float32)
    ls = tf.constant(label_smoothing, tf.float32)
    def loss_fn(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        if label_smoothing > 0:
            y_true = y_true * (1.0 - ls) + 0.5 * ls
        eps = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        bce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        weights = y_true * w1 + (1.0 - y_true) * w0
        return tf.reduce_mean(weights * bce)
    return loss_fn

def focal_bce_loss(gamma=FOCAL_GAMMA, alpha=None, label_smoothing=LABEL_SMOOTH):
    if alpha is None:
        alpha = FOCAL_ALPHA
    alpha = tf.constant(float(alpha), tf.float32)
    gamma = tf.constant(float(gamma), tf.float32)
    ls = tf.constant(float(label_smoothing), tf.float32)
    def loss_fn(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        if label_smoothing > 0:
            y_true = y_true * (1.0 - ls) + 0.5 * ls
        eps = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        bce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        pt = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        alpha_t = y_true * alpha + (1.0 - y_true) * (1.0 - alpha)
        return tf.reduce_mean(alpha_t * tf.pow(1.0 - pt, gamma) * bce)
    return loss_fn

def get_loss():
    return focal_bce_loss() if USE_FOCAL_LOSS else weighted_bce_loss()

class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, peak_lr, total_steps, warmup_steps, min_lr=MIN_LR):
        super().__init__()
        self.peak_lr = float(peak_lr)
        self.total_steps = int(total_steps)
        self.warmup_steps = int(max(warmup_steps, 1))
        self.min_lr = float(min_lr)
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warmup = self.peak_lr * step / float(self.warmup_steps)
        progress = tf.clip_by_value((step - self.warmup_steps) / max(float(self.total_steps - self.warmup_steps), 1.0), 0.0, 1.0)
        cosine = self.min_lr + 0.5 * (self.peak_lr - self.min_lr) * (1.0 + tf.cos(math.pi * progress))
        return tf.where(step < self.warmup_steps, warmup, cosine)
    def get_config(self):
        return {"peak_lr": self.peak_lr, "total_steps": self.total_steps, "warmup_steps": self.warmup_steps, "min_lr": self.min_lr}

def make_lr(lr, epochs):
    total_steps = max(epochs * steps_per_epoch, 1)
    warmup_steps = max(int(total_steps * WARMUP_FRAC), 1)
    return WarmupCosine(lr, total_steps, warmup_steps, MIN_LR)

def make_optimizer(lr_schedule):
    # AdamW fallback for older TF builds.
    try:
        return optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, clipnorm=CLIPNORM)
    except Exception:
        print("AdamW unavailable; using Adam fallback.")
        return optimizers.Adam(learning_rate=lr_schedule, clipnorm=CLIPNORM)

METRICS = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy", threshold=0.5),
    tf.keras.metrics.AUC(name="auc", curve="ROC", num_thresholds=200),
    tf.keras.metrics.AUC(name="pr_auc", curve="PR", num_thresholds=200),
    tf.keras.metrics.Precision(name="precision", thresholds=0.5),
    tf.keras.metrics.Recall(name="recall", thresholds=0.5),
]

class TopKSnapshotter(callbacks.Callback):
    def __init__(self, folder, prefix, k=TOP_K_SNAPSHOTS, monitor="val_auc"):
        super().__init__()
        self.folder = Path(folder)
        self.folder.mkdir(parents=True, exist_ok=True)
        self.prefix = prefix
        self.k = int(k)
        self.monitor = monitor
        self.records = []
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        score = logs.get(self.monitor)
        if score is None or not np.isfinite(score):
            return
        path = self.folder / f"{self.prefix}_epoch{epoch+1:03d}_{self.monitor}{float(score):.5f}.weights.h5"
        self.model.save_weights(str(path))
        self.records.append((float(score), str(path)))
        self.records = sorted(self.records, key=lambda x: x[0], reverse=True)
        for _, old in self.records[self.k:]:
            try:
                os.remove(old)
            except OSError:
                pass
        self.records = self.records[:self.k]
    def get_paths(self):
        return [p for _, p in sorted(self.records, key=lambda x: x[0], reverse=True) if os.path.exists(p)]

def set_vgg_trainability(base_model, trainable_blocks):
    """Train selected VGG blocks only; head layers remain trainable."""
    trainable_blocks = tuple(trainable_blocks)
    for layer in base_model.layers:
        layer.trainable = any(layer.name.startswith(b) for b in trainable_blocks)
    # Make sure custom head stays trainable.
    for layer in model.layers:
        if layer.name.startswith(HEAD_LAYER_PREFIXES):
            layer.trainable = True
    n_train = sum(tf.size(w).numpy() for w in model.trainable_weights)
    print(f"Trainable params now: {n_train:,}")
    print("Trainable VGG layers:", [l.name for l in base_model.layers if l.trainable][-12:])

def compile_model(lr, epochs):
    model.compile(
        optimizer=make_optimizer(make_lr(lr, epochs)),
        loss=get_loss(),
        metrics=METRICS,
    )

def predict_probs(weight_path, ds):
    model.load_weights(weight_path)
    return model.predict(ds, verbose=0).reshape(-1)

def select_best_candidate(candidates, val_ds, y_val, tag):
    rows = []
    for name, path in candidates:
        if path and os.path.exists(path):
            p = predict_probs(path, val_ds)
            auc = roc_auc_score(y_val, p)
            rows.append({"name": name, "path": path, "val_auc": float(auc)})
            print(f"{tag:<8} {name:<22} val_auc={auc:.5f}")
    assert rows, f"No valid candidates for {tag}"
    df = pd.DataFrame(rows).sort_values("val_auc", ascending=False).reset_index(drop=True)
    df.to_csv(SAVE_DIR / f"{tag}_candidate_val_auc.csv", index=False)
    return df.iloc[0].to_dict(), df

# %%
# ======================================================================================
# CELL 8 — Phase 1: train classification head
# ======================================================================================
print("\n" + "=" * 80)
print("PHASE 1 — Head training, frozen VGG19 backbone")
print("=" * 80)

base.trainable = False
for layer in model.layers:
    if layer.name.startswith(HEAD_LAYER_PREFIXES):
        layer.trainable = True

phase1_ckpt = str(SAVE_DIR / "phase1_best.weights.h5")
snap_p1 = TopKSnapshotter(SAVE_DIR / "snapshots_phase1", prefix="p1")
compile_model(PHASE1_LR, PHASE1_EPOCHS)

history_p1 = model.fit(
    train_ds_mix if USE_BATCH_MIXING else train_ds_clean,
    epochs=PHASE1_EPOCHS,
    validation_data=val_ds,
    callbacks=[
        callbacks.ModelCheckpoint(phase1_ckpt, monitor="val_auc", mode="max", save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=7, restore_best_weights=True, verbose=1),
        callbacks.CSVLogger(str(SAVE_DIR / "phase1_history.csv")),
        callbacks.TerminateOnNaN(),
        snap_p1,
    ],
    verbose=1,
)
print(f"Phase 1 best val_AUC = {max(history_p1.history.get('val_auc', [0])):.5f}")
# Out:
# ================================================================================
# PHASE 1 — Head training, frozen VGG19 backbone
# ================================================================================
# Epoch 1/16
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5391 - auc: 0.5639 - loss: 0.7815 - pr_auc: 0.4659 - precision: 0.4615 - recall: 0.6063
# Epoch 1: val_auc improved from None to 0.67914, saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase1_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase1_best.weights.h5
# 155/155 ━━━━━━━━━━━━━━━━━━━━
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Phase 1 best val_AUC = 0.73291

# %%
# ======================================================================================
# CELL 9 — Phase 2: fine-tune VGG block5
# ======================================================================================
print("\n" + "=" * 80)
print("PHASE 2 — Fine-tune VGG block5")
print("=" * 80)

model.load_weights(phase1_ckpt)
set_vgg_trainability(base, trainable_blocks=["block5"])

phase2_ckpt = str(SAVE_DIR / "phase2_best.weights.h5")
snap_p2 = TopKSnapshotter(SAVE_DIR / "snapshots_phase2", prefix="p2")
compile_model(PHASE2_LR, PHASE2_EPOCHS)

history_p2 = model.fit(
    train_ds_clean,
    epochs=PHASE2_EPOCHS,
    validation_data=val_ds,
    callbacks=[
        callbacks.ModelCheckpoint(phase2_ckpt, monitor="val_auc", mode="max", save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=12, restore_best_weights=True, verbose=1),
        callbacks.CSVLogger(str(SAVE_DIR / "phase2_history.csv")),
        callbacks.TerminateOnNaN(),
        snap_p2,
    ],
    verbose=1,
)
print(f"Phase 2 best val_AUC = {max(history_p2.history.get('val_auc', [0])):.5f}")

# Select best so far by clean validation AUC.
y_val = val_df["label"].astype(int).values
p1_paths = [("phase1_best", phase1_ckpt)] + [(f"p1_snapshot_{i+1}", p) for i, p in enumerate(snap_p1.get_paths())]
p2_paths = [("phase2_best", phase2_ckpt)] + [(f"p2_snapshot_{i+1}", p) for i, p in enumerate(snap_p2.get_paths())]
best_p2, p2_df = select_best_candidate(p1_paths + p2_paths, val_ds, y_val, tag="phase2")
selected_p2_path = str(SAVE_DIR / "phase2_selected_best.weights.h5")
model.load_weights(best_p2["path"])
model.save_weights(selected_p2_path)
print("Selected after Phase 2:", best_p2)
# Out:
# ================================================================================
# PHASE 2 — Fine-tune VGG block5
# ================================================================================
# Trainable params now: 10,131,585
# Trainable VGG layers: ['block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
# Epoch 1/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6525 - auc: 0.7403 - loss: 0.6130 - pr_auc: 0.6564 - precision: 0.5530 - recall: 0.7392
# Epoch 1: val_auc improved from None to 0.73818, saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase2_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase2_best.weights.h5
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 34s 118ms/step - accuracy: 0.6538 - auc: 0.7420 - loss: 0.6204 - pr_auc: 0.6552 - precision: 0.5557 - recall: 0.7271 - val_accuracy: 0.6427 - val_auc: 0.7382 - val_loss: 0.6285 - val_pr_auc: 0.6515 - val_precision: 0.5437 - val_recall: 0.7273
# Epoch 2/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6827 - auc: 0.7678 - loss: 0.6009 - pr_auc: 0.6787 - precision: 0.5834 - recall: 0.7223
# Epoch 2: val_auc did not improve from 0.73818
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.6850 - auc: 0.7679 - loss: 0.6037 - pr_auc: 0.6745 - precision: 0.5906 - recall: 0.7271 - val_accuracy: 0.6567 - val_auc: 0.7379 - val_loss: 0.6353 - val_pr_auc: 0.6461 - val_precision: 0.5566 - val_recall: 0.7446
# Epoch 3/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.
45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8407 - auc: 0.9253 - loss: 0.3881 - pr_auc: 0.8781 - precision: 0.7686 - recall: 0.8736
# Epoch 30: val_auc did not improve from 0.77629
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8320 - auc: 0.9187 - loss: 0.3985 - pr_auc: 0.8740 - precision: 0.7557 - recall: 0.8655 - val_accuracy: 0.6970 - val_auc: 0.7703 - val_loss: 0.6530 - val_pr_auc: 0.6889 - val_precision: 0.6115 - val_recall: 0.6883
# Epoch 31/45
# 154/155 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8514 - auc: 0.9279 - loss: 0.3834 - pr_auc: 0.8957 - precision: 0.7851 - recall: 0.8885
# Epoch 31: val_auc did not improve from 0.77629
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8401 - auc: 0.9137 - loss: 0.4072 - pr_auc: 0.8665 - precision: 0.7639 - recall: 0.8765 - val_accuracy: 0.6865 - val_auc: 0.7619 - val_loss: 0.6709 - val_pr_auc: 0.6790 - val_precision: 0.6182 - val_recall: 0.5887
# Epoch 32/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8501 - auc: 0.9248 - loss: 0.3893 - pr_auc: 0.8892 - precision: 0.7865 - recall: 0.8771
# Epoch 32: val_auc did not improve from 0.77629
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8461 - auc: 0.9250 - loss: 0.3856 - pr_auc: 0.8874 - precision: 0.7735 - recall: 0.8775 - val_accuracy: 0.6988 - val_auc: 0.7684 - val_loss: 0.6611 - val_pr_auc: 0.6894 - val_precision: 0.5961 - val_recall: 0.7922
# Epoch 33/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8579 - auc: 0.9300 - loss: 0.3796 - pr_auc: 0.8862 - precision: 0.7913 - recall: 0.8870
# Epoch 33: val_auc did not improve from 0.77629
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8473 - auc: 0.9264 - loss: 0.3838 - pr_auc: 0.8862 - precision: 0.7712 - recall: 0.8865 - val_accuracy: 0.6813 - val_auc: 0.7682 - val_loss: 0.6435 - val_pr_auc: 0.6886 - val_precision: 0.5946 - val_recall: 0.6667
# Epoch 34/45
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8255 - auc: 0.9145 - loss: 0.4051 - pr_auc: 0.8635 - precision: 0.7431 - recall: 0.8818
# Epoch 34: val_auc did not improve from 0.77629
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8364 - auc: 0.9211 - loss: 0.3944 - pr_auc: 0.8724 - precision: 0.7540 - recall: 0.8855 - val_accuracy: 0.6760 - val_auc: 0.7586 - val_loss: 0.6765 - val_pr_auc: 0.6814 - val_precision: 0.5935 - val_recall: 0.6320
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Phase 2 best val_AUC = 0.77629
# phase2   phase1_best            val_auc=0.73272
# phase2   p1_snapshot_1          val_auc=0.73272
# phase2   p1_snapshot_2          val_auc=0.72951
# phase2   p1_snapshot_3          val_auc=0.71724
# phase2   p1_snapshot_4          val_auc=0.71748
# phase2   phase2_best            val_auc=0.77653
# phase2   p2_snapshot_1          val_auc=0.77653
# phase2   p2_snapshot_2          val_auc=0.77497
# phase2   p2_snapshot_3          val_auc=0.77352
# phase2   p2_snapshot_4          val_auc=0.77289
# Selected after Phase 2: {'name': 'p2_snapshot_1', 'path': '/content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/snapshots_phase2/p2_epoch022_val_auc0.77629.weights.h5', 'val_auc': 0.7765342500636618}

# %%
# ======================================================================================
# CELL 10 — Phase 3: polish block4 + block5 at tiny LR
# ======================================================================================
print("\n" + "=" * 80)
print("PHASE 3 — Tiny-LR polish on VGG block4 + block5")
print("=" * 80)

model.load_weights(selected_p2_path)
set_vgg_trainability(base, trainable_blocks=["block4", "block5"])

phase3_ckpt = str(SAVE_DIR / "phase3_best.weights.h5")
snap_p3 = TopKSnapshotter(SAVE_DIR / "snapshots_phase3", prefix="p3")
compile_model(PHASE3_LR, PHASE3_EPOCHS)

history_p3 = model.fit(
    train_ds_clean,
    epochs=PHASE3_EPOCHS,
    validation_data=val_ds,
    callbacks=[
        callbacks.ModelCheckpoint(phase3_ckpt, monitor="val_auc", mode="max", save_best_only=True, save_weights_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_auc", mode="max", patience=10, restore_best_weights=True, verbose=1),
        callbacks.CSVLogger(str(SAVE_DIR / "phase3_history.csv")),
        callbacks.TerminateOnNaN(),
        snap_p3,
    ],
    verbose=1,
)
print(f"Phase 3 best val_AUC = {max(history_p3.history.get('val_auc', [0])):.5f}")

candidate_pool = [
    ("phase1_best", phase1_ckpt),
    ("phase2_best", phase2_ckpt),
    ("phase2_selected", selected_p2_path),
    ("phase3_best", phase3_ckpt),
]
candidate_pool += [(f"p1_snapshot_{i+1}", p) for i, p in enumerate(snap_p1.get_paths())]
candidate_pool += [(f"p2_snapshot_{i+1}", p) for i, p in enumerate(snap_p2.get_paths())]
candidate_pool += [(f"p3_snapshot_{i+1}", p) for i, p in enumerate(snap_p3.get_paths())]

best_final, candidate_df = select_best_candidate(candidate_pool, val_ds, y_val, tag="final")
final_single_path = str(SAVE_DIR / "final_single_best.weights.h5")
model.load_weights(best_final["path"])
model.save_weights(final_single_path)
model.save(str(SAVE_DIR / "vgg19_ultra_v5_final_single.keras"))
print("Final selected single checkpoint:", best_final)
# Out:
# ================================================================================
# PHASE 3 — Tiny-LR polish on VGG block4 + block5
# ================================================================================
# Trainable params now: 18,391,169
# Trainable VGG layers: ['block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_conv4', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
# Epoch 1/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7619 - auc: 0.8444 - loss: 0.4353 - pr_auc: 0.7805 - precision: 0.6824 - recall: 0.7734
# Epoch 1: val_auc improved from None to 0.77275, saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase3_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase3_best.weights.h5
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 141ms/step - accuracy: 0.7837 - auc: 0.8681 - loss: 0.4434 - pr_auc: 0.8110 - precision: 0.7028 - recall: 0.8081 - val_accuracy: 0.6848 - val_auc: 0.7728 - val_loss: 0.6115 - val_pr_auc: 0.6836 - val_precision: 0.5882 - val_recall: 0.7359
# Epoch 2/25
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8317 - auc: 0.9161 - loss: 0.4111 - pr_auc: 0.8695 - precision: 0.7413 - recall: 0.8768
# Epoch 2: val_auc improved from 0.77275 to 0.77317, saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase3_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase3_best.weights.h5
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8344 - auc: 0.9167 - loss: 0.4045 - pr_auc: 0.8775 - precision: 0.7569 - recall: 0.8715 - val_accuracy: 0.6988 - val_auc: 0.7605 - val_loss: 0.6597 - val_pr_auc: 0.6864 - val_precision: 0.6288 - val_recall: 0.6234
# Epoch 10/25
# 153/155 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8393 - auc: 0.9220 - loss: 0.3943 - pr_auc: 0.8816 - precision: 0.7585 - recall: 0.8639
# Epoch 10: val_auc did not improve from 0.77317
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8320 - auc: 0.9159 - loss: 0.4061 - pr_auc: 0.8720 - precision: 0.7565 - recall: 0.8635 - val_accuracy: 0.6760 - val_auc: 0.7543 - val_loss: 0.6687 - val_pr_auc: 0.6725 - val_precision: 0.5767 - val_recall: 0.7489
# Epoch 11/25
# 153/155 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8319 - auc: 0.9227 - loss: 0.3957 - pr_auc: 0.8753 - precision: 0.7438 - recall: 0.8851
# Epoch 11: val_auc did not improve from 0.77317
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8352 - auc: 0.9223 - loss: 0.3926 - pr_auc: 0.8810 - precision: 0.7573 - recall: 0.8735 - val_accuracy: 0.6813 - val_auc: 0.7641 - val_loss: 0.6456 - val_pr_auc: 0.6860 - val_precision: 0.5904 - val_recall: 0.6926
# Epoch 12/25
# 153/155 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8604 - auc: 0.9293 - loss: 0.3833 - pr_auc: 0.9045 - precision: 0.8074 - recall: 0.8790
# Epoch 12: val_auc did not improve from 0.77317
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8481 - auc: 0.9236 - loss: 0.3918 - pr_auc: 0.8858 - precision: 0.7759 - recall: 0.8795 - val_accuracy: 0.6970 - val_auc: 0.7498 - val_loss: 0.6910 - val_pr_auc: 0.6770 - val_precision: 0.6160 - val_recall: 0.6667
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 2.
# Phase 3 best val_AUC = 0.77317
# final    phase1_best            val_auc=0.73272
# final    phase2_best            val_auc=0.77653
# final    phase2_selected        val_auc=0.77653
# final    phase3_best            val_auc=0.77315
# final    p1_snapshot_1          val_auc=0.73272
# final    p1_snapshot_2          val_auc=0.72951
# final    p1_snapshot_3          val_auc=0.71724
# final    p1_snapshot_4          val_auc=0.71748
# final    p2_snapshot_1          val_auc=0.77653
# final    p2_snapshot_2          val_auc=0.77497
# final    p2_snapshot_3          val_auc=0.77352
# final    p2_snapshot_4          val_auc=0.77289
# final    p3_snapshot_1          val_auc=0.77315
# final    p3_snapshot_2          val_auc=0.77269
# final    p3_snapshot_3          val_auc=0.76814
# final    p3_snapshot_4          val_auc=0.76450
# Final selected single checkpoint: {'name': 'phase2_best', 'path': '/content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/phase2_best.weights.h5', 'val_auc': 0.7765342500636618}

# %%
# ======================================================================================
# CELL 11 — Candidate probability ensemble + deterministic TTA
# ======================================================================================
print("\n" + "=" * 80)
print("FINAL CANDIDATE SELECTION + TTA")
print("=" * 80)

y_val = val_df["label"].astype(int).values
y_test = test_df["label"].astype(int).values

# Clean validation candidate ranking.
clean_rows = []
val_probs_by_name = {}
for name, path in candidate_pool + [("final_single", final_single_path)]:
    if path is None or not os.path.exists(path):
        continue
    p = predict_probs(path, val_ds)
    auc = roc_auc_score(y_val, p)
    clean_rows.append({"name": name, "path": path, "clean_val_auc": float(auc)})
    val_probs_by_name[name] = p
    print(f"{name:<22} clean val_auc={auc:.5f}")

clean_df = pd.DataFrame(clean_rows).drop_duplicates(subset=["path"]).sort_values("clean_val_auc", ascending=False).reset_index(drop=True)
clean_df.to_csv(SAVE_DIR / "all_candidate_clean_val_auc.csv", index=False)

best_single_name = clean_df.loc[0, "name"]
best_single_path = clean_df.loc[0, "path"]
best_single_auc  = float(clean_df.loc[0, "clean_val_auc"])

# Top-N probability ensemble. Use only if validation AUC improves.
topn = clean_df.head(min(3, len(clean_df)))
topn_names = topn["name"].tolist()
topn_paths = topn["path"].tolist()
ens_val_clean = np.mean([val_probs_by_name[n] for n in topn_names], axis=0)
ens_clean_auc = roc_auc_score(y_val, ens_val_clean)

print("\nClean validation comparison")
print(f"Best single : {best_single_name} AUC={best_single_auc:.5f}")
print(f"Top ensemble: {topn_names} AUC={ens_clean_auc:.5f}")

USE_ENSEMBLE = ens_clean_auc >= best_single_auc + 0.001
if USE_ENSEMBLE:
    final_weight_paths = topn_paths
    print("→ Using validation-improving top checkpoint probability ensemble.")
else:
    final_weight_paths = [best_single_path]
    print("→ Using best single checkpoint; ensemble did not improve validation AUC enough.")

def tta_predict_weight_files(weight_paths, static_ds, n_tta=TTA_STEPS, name="set"):
    per_model_probs = []
    n_tta = min(int(n_tta), 8)
    for wi, wpath in enumerate(weight_paths, start=1):
        print(f"\nWeights {wi}/{len(weight_paths)}: {Path(wpath).name}")
        model.load_weights(wpath)
        view_probs = []
        for t in range(n_tta):
            ds_tta = make_tta_ds(static_ds, t)
            p = model.predict(ds_tta, verbose=0).reshape(-1)
            view_probs.append(p)
            print(f"  {name} TTA {t+1}/{n_tta}: mean={p.mean():.5f}")
        per_model_probs.append(np.mean(view_probs, axis=0))
    return np.mean(per_model_probs, axis=0)

print("\nPredicting validation with final TTA setup...")
val_prob = tta_predict_weight_files(final_weight_paths, val_static, n_tta=TTA_STEPS, name="val")

print("\nPredicting test with final TTA setup...")
test_prob = tta_predict_weight_files(final_weight_paths, test_static, n_tta=TTA_STEPS, name="test")

print(f"\nVal TTA AUC : {roc_auc_score(y_val, val_prob):.5f}")
print(f"Test prob range: [{test_prob.min():.5f}, {test_prob.max():.5f}], mean={test_prob.mean():.5f}")
# Out:
# ================================================================================
# FINAL CANDIDATE SELECTION + TTA
# ================================================================================
# phase1_best            clean val_auc=0.73272
# phase2_best            clean val_auc=0.77653
# phase2_selected        clean val_auc=0.77653
# phase3_best            clean val_auc=0.77315
# p1_snapshot_1          clean val_auc=0.73272
# p1_snapshot_2          clean val_auc=0.72951
# p1_snapshot_3          clean val_auc=0.71724
# p1_snapshot_4          clean val_auc=0.71748
# p2_snapshot_1          clean val_auc=0.77653
# p2_snapshot_2          clean val_auc=0.77497
# p2_snapshot_3          clean val_auc=0.77352
# p2_snapshot_4          clean val_auc=0.77289
# p3_snapshot_1          clean val_auc=0.77315
# p3_snapshot_2          clean val_auc=0.77269
# p3_snapshot_3          clean val_auc=0.76814
# p3_snapshot_4          clean val_auc=0.76450
# final_single           clean val_auc=0.77653
#
# Clean validation comparison
# Best single : phase2_best AUC=0.77653
# Top ensemble: ['phase2_best', 'p2_snapshot_1', 'phase2_selected'] AUC=0.77653
# → Using best single checkpoint; ensemble did not improve validation AUC enough.
#
# Predicting validation with final TTA setup...
#
# Weights 1/1: phase2_best.weights.h5
#   val TTA 1/8: mean=0.55004
#   val TTA 2/8: mean=0.54966
#   val TTA 3/8: mean=0.53759
#   val TTA 4/8: mean=0.53829
#   val TTA 5/8: mean=0.53845
#   val TTA 6/8: mean=0.53829
#   val TTA 7/8: mean=0.55267
#   val TTA 8/8: mean=0.54401
#
# Predicting test with final TTA setup...
#
# Weights 1/1: phase2_best.weights.h5
#   test TTA 1/8: mean=0.59174
#   test TTA 2/8: mean=0.59415
#   test TTA 3/8: mean=0.58823
#   test TTA 4/8: mean=0.58921
#   test TTA 5/8: mean=0.59279
#   test TTA 6/8: mean=0.58921
#   test TTA 7/8: mean=0.58644
#   test TTA 8/8: mean=0.58853
#
# Val TTA AUC : 0.79582
# Test prob range: [0.00337, 0.99959], mean=0.59004

# %%
# ======================================================================================
# CELL 12 — Validation-only threshold tuning + final test evaluation
# ======================================================================================
def metric_at_threshold(y_true, y_prob, thr):
    y_pred = (y_prob >= thr).astype(int)
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    acc = accuracy_score(y_true, y_pred)
    bal = balanced_accuracy_score(y_true, y_pred)
    sens = tp / max(tp + fn, 1)
    spec = tn / max(tn + fp, 1)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    npv = tn / max(tn + fn, 1)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    mcc = matthews_corrcoef(y_true, y_pred) if len(np.unique(y_pred)) > 1 else 0.0
    return {
        "thr": float(thr), "acc": float(acc), "bal_acc": float(bal),
        "sensitivity": float(sens), "specificity": float(spec),
        "precision": float(prec), "recall": float(rec), "npv": float(npv),
        "f1": float(f1), "mcc": float(mcc),
        "tp": int(tp), "tn": int(tn), "fp": int(fp), "fn": int(fn),
    }

def build_threshold_table(y_true, y_prob):
    grid = np.linspace(0.05, 0.95, 181)
    rows = [metric_at_threshold(y_true, y_prob, t) for t in grid]
    df = pd.DataFrame(rows)
    fpr, tpr, thr_roc = roc_curve(y_true, y_prob)
    finite = np.isfinite(thr_roc)
    youden_thr = float(thr_roc[finite][np.argmax((tpr - fpr)[finite])]) if finite.any() else 0.5
    best_bal = float(df.loc[df["bal_acc"].idxmax(), "thr"])
    best_f1  = float(df.loc[df["f1"].idxmax(), "thr"])
    best_mcc = float(df.loc[df["mcc"].idxmax(), "thr"])
    robust_thr = float(np.median([best_bal, best_mcc, youden_thr]))
    robust_thr = float(np.clip(robust_thr, 0.05, 0.95))
    return df, {
        "thr_0.50": 0.50,
        "thr_bal_acc": best_bal,
        "thr_f1": best_f1,
        "thr_mcc": best_mcc,
        "thr_youden": youden_thr,
        "thr_robust": robust_thr,
    }

thr_df, thresholds = build_threshold_table(y_val, val_prob)
thr_df.to_csv(SAVE_DIR / "validation_threshold_search.csv", index=False)

print("\nValidation thresholds")
for k, v in thresholds.items():
    print(f"{k:<14}: {v:.5f}")

OPT_THR = thresholds["thr_robust"]
print(f"\n→ Selected robust validation threshold: {OPT_THR:.5f}")

auc_roc = roc_auc_score(y_test, test_prob)
pr_auc = average_precision_score(y_test, test_prob)
metrics_050 = metric_at_threshold(y_test, test_prob, 0.50)
metrics_opt = metric_at_threshold(y_test, test_prob, OPT_THR)

def print_metric_block(title, m):
    print(f"\n{title}")
    print("-" * len(title))
    print(f"Acc={m['acc']:.4f} | BalAcc={m['bal_acc']:.4f} | F1={m['f1']:.4f} | MCC={m['mcc']:.4f}")
    print(f"Sens={m['sensitivity']:.4f} | Spec={m['specificity']:.4f} | Prec={m['precision']:.4f} | NPV={m['npv']:.4f}")
    print(f"TP={m['tp']} TN={m['tn']} FP={m['fp']} FN={m['fn']}")

print("\n" + "=" * 80)
print("FINAL TEST RESULTS")
print("=" * 80)
print(f"ROC-AUC : {auc_roc:.5f}")
print(f"PR-AUC  : {pr_auc:.5f}")
print_metric_block("Threshold = 0.50", metrics_050)
print_metric_block(f"Threshold = {OPT_THR:.5f} (validation robust)", metrics_opt)

y_pred_opt = (test_prob >= OPT_THR).astype(int)
print("\nClassification report")
print(classification_report(y_test, y_pred_opt, target_names=["benign", "malignant"], digits=4, zero_division=0))

pred_df = pd.DataFrame({
    "path": test_df["path"].values,
    "true_label": y_test,
    "prob_malignant": test_prob,
    "pred_label": y_pred_opt,
})
pred_df.to_csv(SAVE_DIR / "test_predictions_tta.csv", index=False)

summary = {
    "model": MODEL_NAME,
    "img_size": IMG_SIZE,
    "resize_size": RESIZE_SIZE,
    "batch_size": BATCH_SIZE,
    "train_count": len(train_df),
    "val_count": len(val_df),
    "test_count": len(test_df),
    "loss": "focal_bce" if USE_FOCAL_LOSS else "weighted_bce",
    "tta_steps": TTA_STEPS,
    "used_ensemble": bool(USE_ENSEMBLE),
    "ensemble_members": "|".join([Path(p).name for p in final_weight_paths]),
    "opt_threshold": float(OPT_THR),
    "auc_roc": float(auc_roc),
    "pr_auc": float(pr_auc),
    **{f"test_{k}": v for k, v in metrics_opt.items()},
}
pd.DataFrame([summary]).to_csv(SAVE_DIR / "results_summary.csv", index=False)

print(f"\nSaved results to: {SAVE_DIR}")
# Out:
# Validation thresholds
# thr_0.50      : 0.50000
# thr_bal_acc   : 0.56500
# thr_f1        : 0.50500
# thr_mcc       : 0.56500
# thr_youden    : 0.56573
# thr_robust    : 0.56500
#
# → Selected robust validation threshold: 0.56500
#
# ================================================================================
# FINAL TEST RESULTS
# ================================================================================
# ROC-AUC : 0.81776
# PR-AUC  : 0.79330
#
# Threshold = 0.50
# ----------------
# Acc=0.6454 | BalAcc=0.6736 | F1=0.6775 | MCC=0.3657
# Sens=0.8698 | Spec=0.4774 | Prec=0.5549 | NPV=0.8303
# TP=187 TN=137 FP=150 FN=28
#
# Threshold = 0.56500 (validation robust)
# ---------------------------------------
# Acc=0.6853 | BalAcc=0.7049 | F1=0.6962 | MCC=0.4153
# Sens=0.8419 | Spec=0.5679 | Prec=0.5934 | NPV=0.8274
# TP=181 TN=163 FP=124 FN=34
#
# Classification report
#               precision    recall  f1-score   support
#
#       benign     0.8274    0.5679    0.6736       287
#    malignant     0.5934    0.8419    0.6962       215
#
#     accuracy                         0.6853       502
#    macro avg     0.7104    0.7049    0.6849       502
# weighted avg     0.7272    0.6853    0.6832       502
#
#
# Saved results to: /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai

# %%
# ======================================================================================
# CELL 13 — Plots and final dashboard
# ======================================================================================
fpr, tpr, _ = roc_curve(y_test, test_prob)
prec_curve, rec_curve, _ = precision_recall_curve(y_test, test_prob)
cm = confusion_matrix(y_test, y_pred_opt, labels=[0, 1])

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[0],
            xticklabels=["Pred benign", "Pred malignant"],
            yticklabels=["True benign", "True malignant"])
axes[0].set_title(f"Confusion Matrix | thr={OPT_THR:.3f}")

axes[1].plot(fpr, tpr, lw=2, label=f"AUC={auc_roc:.4f}")
axes[1].plot([0, 1], [0, 1], "--", alpha=0.7)
axes[1].set_xlabel("False Positive Rate")
axes[1].set_ylabel("True Positive Rate")
axes[1].set_title("ROC Curve")
axes[1].grid(alpha=0.3)
axes[1].legend()

axes[2].plot(rec_curve, prec_curve, lw=2, label=f"AP={pr_auc:.4f}")
axes[2].set_xlabel("Recall")
axes[2].set_ylabel("Precision")
axes[2].set_title("Precision-Recall Curve")
axes[2].grid(alpha=0.3)
axes[2].legend()

plt.tight_layout()
plt.savefig(SAVE_DIR / "final_eval_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# Training curve plot.
def get_hist(h, key):
    return list(h.history.get(key, []))

all_hist = {
    "loss": get_hist(history_p1, "loss") + get_hist(history_p2, "loss") + get_hist(history_p3, "loss"),
    "val_loss": get_hist(history_p1, "val_loss") + get_hist(history_p2, "val_loss") + get_hist(history_p3, "val_loss"),
    "auc": get_hist(history_p1, "auc") + get_hist(history_p2, "auc") + get_hist(history_p3, "auc"),
    "val_auc": get_hist(history_p1, "val_auc") + get_hist(history_p2, "val_auc") + get_hist(history_p3, "val_auc"),
    "pr_auc": get_hist(history_p1, "pr_auc") + get_hist(history_p2, "pr_auc") + get_hist(history_p3, "pr_auc"),
    "val_pr_auc": get_hist(history_p1, "val_pr_auc") + get_hist(history_p2, "val_pr_auc") + get_hist(history_p3, "val_pr_auc"),
}

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, tr, va, title in [
    (axes[0], "loss", "val_loss", "Loss"),
    (axes[1], "auc", "val_auc", "ROC-AUC"),
    (axes[2], "pr_auc", "val_pr_auc", "PR-AUC"),
]:
    ax.plot(all_hist[tr], label="train")
    ax.plot(all_hist[va], label="val")
    ax.axvline(len(get_hist(history_p1, "loss")) - 1, color="gray", ls="--", alpha=0.6)
    ax.axvline(len(get_hist(history_p1, "loss")) + len(get_hist(history_p2, "loss")) - 1, color="gray", ls="--", alpha=0.6)
    ax.set_title(title)
    ax.grid(alpha=0.3)
    ax.legend()
plt.tight_layout()
plt.savefig(SAVE_DIR / "training_history.png", dpi=150, bbox_inches="tight")
plt.show()

print("✅ VGG19_ULTRA_V5_FIXED complete.")
print(f"ROC-AUC={auc_roc:.5f} | PR-AUC={pr_auc:.5f} | F1={metrics_opt['f1']:.5f}")
print(f"Sensitivity={metrics_opt['sensitivity']:.5f} | Specificity={metrics_opt['specificity']:.5f}")
# Out:
# ✅ VGG19_ULTRA_V5_FIXED complete.
# ROC-AUC=0.81776 | PR-AUC=0.79330 | F1=0.69615
# Sensitivity=0.84186 | Specificity=0.56794

# %%
# ============================================================================
# CELL 18 - VGG19 Old vs New Comprehensive Comparison Dashboard
# ============================================================================

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
from pathlib import Path

from sklearn.metrics import (
    confusion_matrix,
    roc_curve,
    precision_recall_curve,
    roc_auc_score,
    average_precision_score,
    f1_score,
    matthews_corrcoef,
    balanced_accuracy_score,
)

# ── Safety check ─────────────────────────────────────────────────────────────
# Supports both common variable styles:
#   V6 notebook may use y_test/test_prob
#   other notebooks may use y_true/y_prob
if "y_test" in globals():
    y_true = y_test

if "test_prob" in globals():
    y_prob = test_prob

_required = ["y_true", "y_prob", "SAVE_DIR"]
_missing = [v for v in _required if v not in globals()]
if _missing:
    raise RuntimeError(
        "Run the New VGG19 final test evaluation cells first. "
        f"Missing variables: {_missing}"
    )

if "OPT_THR" in globals():
    OPTIMAL_THRESHOLD = float(OPT_THR)
elif "OPTIMAL_THRESHOLD" not in globals():
    print("⚠️ OPTIMAL_THRESHOLD not found. Using threshold=0.50.")
    OPTIMAL_THRESHOLD = 0.50

# ── Helpers ─────────────────────────────────────────────────────────────────
def status_color(auc):
    if auc >= 0.80:
        return "#27AE60"
    if auc >= 0.75:
        return "#2980B9"
    if auc >= 0.65:
        return "#F39C12"
    return "#E74C3C"

def status_label(auc):
    if auc >= 0.80:
        return "GREAT"
    if auc >= 0.75:
        return "GOOD"
    if auc >= 0.65:
        return "FAIR"
    return "FAILED"

def clean_ax(ax, axis="both"):
    ax.grid(axis=axis, alpha=0.25)
    ax.spines[["top", "right"]].set_visible(False)

def safe_div(a, b):
    return 0.0 if b == 0 else a / b

# ── Current New VGG19 metrics from live notebook arrays ──────────────────────
y_true_dash = np.asarray(y_true).astype(int)
y_prob_dash = np.asarray(y_prob).astype(float)
y_pred_dash = (y_prob_dash >= float(OPTIMAL_THRESHOLD)).astype(int)

cm_new = confusion_matrix(y_true_dash, y_pred_dash, labels=[0, 1])
_tn, _fp, _fn, _tp = [int(x) for x in cm_new.ravel()]

_acc  = safe_div(_tp + _tn, _tp + _tn + _fp + _fn)
_sens = safe_div(_tp, _tp + _fn)
_spec = safe_div(_tn, _tn + _fp)
_prec = safe_div(_tp, _tp + _fp)
_f1   = f1_score(y_true_dash, y_pred_dash, zero_division=0)
_mcc  = matthews_corrcoef(y_true_dash, y_pred_dash) if len(set(y_pred_dash)) > 1 else 0.0
_bal  = balanced_accuracy_score(y_true_dash, y_pred_dash)
_auc  = roc_auc_score(y_true_dash, y_prob_dash)
_ap   = average_precision_score(y_true_dash, y_prob_dash)

# ── Model registry ───────────────────────────────────────────────────────────
# Old VGG19 values from the uploaded 6-model final comparison image:
# AUC=.5951, PR-AUC=.5267, Acc=.5797, Sens=.0233, Spec=.9965,
# F1=.0452, MCC=.0900, TN=286, FP=1, FN=210, TP=5.
_b_tp, _b_tn, _b_fp, _b_fn = 5, 286, 1, 210

MODELS = {
    "Old\n(VGG19)": dict(
        color="#E74C3C",
        auc=0.5951,
        pr_auc=0.5267,
        acc=0.5797,
        sens=0.0233,
        spec=0.9965,
        prec=_b_tp / (_b_tp + _b_fp),
        f1=0.0452,
        mcc=0.0900,
        fn=_b_fn,
        tp=_b_tp,
        tn=_b_tn,
        fp=_b_fp,
        n_mal=_b_tp + _b_fn,
        thr=None,
    ),
    "New\n(VGG19)": dict(
        color="#2E86AB",
        auc=float(_auc),
        pr_auc=float(_ap),
        acc=float(_acc),
        sens=float(_sens),
        spec=float(_spec),
        prec=float(_prec),
        f1=float(_f1),
        mcc=float(_mcc),
        fn=int(_fn),
        tp=int(_tp),
        tn=int(_tn),
        fp=int(_fp),
        n_mal=int(_tp + _fn),
        thr=float(OPTIMAL_THRESHOLD),
    ),
}

names = list(MODELS.keys())
colors = [MODELS[n]["color"] for n in names]
best_auc_name = max(names, key=lambda n: MODELS[n]["auc"])

def display_status(nm):
    return "BEST" if nm == best_auc_name else status_label(MODELS[nm]["auc"])

n_test_total = _tp + _tn + _fp + _fn
n_malignant = _tp + _fn

# ── Figure layout ────────────────────────────────────────────────────────────
fig = plt.figure(figsize=(22, 26), facecolor="#F8F9FA")
fig.suptitle(
    f"VGG19 Model Comparison — CBIS-DDSM Breast Cancer  |  Cropped Images"
    f"  (New Test Set, n={n_test_total})",
    fontsize=15,
    fontweight="bold",
    y=0.99,
)

outer = gridspec.GridSpec(
    5, 1,
    figure=fig,
    hspace=0.42,
    top=0.965,
    bottom=0.02,
    left=0.05,
    right=0.98,
)

# ── ROW 0: AUC ranking | sensitivity ranking ────────────────────────────────
row0 = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=outer[0], wspace=0.08)
ax_auc = fig.add_subplot(row0[0])
ax_sens = fig.add_subplot(row0[1])

rank_auc = sorted(names, key=lambda n: MODELS[n]["auc"], reverse=True)
rank_sens = sorted(names, key=lambda n: MODELS[n]["sens"], reverse=True)

for ax, metric, order, title, reflines in [
    (
        ax_auc,
        "auc",
        rank_auc,
        "ROC-AUC Ranking  (primary metric)",
        [
            (0.80, "#27AE60", "Great ≥ 0.80"),
            (0.75, "#2980B9", "Good ≥ 0.75"),
            (0.50, "gray", "Random = 0.50"),
        ],
    ),
    (
        ax_sens,
        "sens",
        rank_sens,
        "Sensitivity (cancer detection rate)  ← most critical",
        [
            (0.80, "#27AE60", "Target ≥ 0.80"),
            (0.65, "#F39C12", "Fair ≥ 0.65"),
        ],
    ),
]:
    vals = [MODELS[n][metric] for n in order]
    cols = [MODELS[n]["color"] for n in order]

    bars = ax.barh(order, vals, color=cols, height=0.5, edgecolor="white", linewidth=0.7)
    ax.invert_yaxis()

    for bar, val, nm in zip(bars, vals, order):
        sc = status_color(MODELS[nm]["auc"])
        label = (
            f"{val:.4f}  [{display_status(nm)}]"
            if metric == "auc"
            else f"{val:.4f}  FN={MODELS[nm]['fn']}"
        )
        ax.text(
            val + 0.005,
            bar.get_y() + bar.get_height() / 2,
            label,
            va="center",
            fontsize=9,
            color=sc,
            fontweight="bold",
        )

    for xv, c, lbl in reflines:
        ax.axvline(xv, color=c, ls="--", lw=1.2, alpha=0.8)

    ax.set_xlim(0, 1.07)
    ax.set_title(title, fontsize=10, fontweight="bold", pad=6)
    ax.tick_params(labelsize=8)
    ax.set_xlabel("Score", fontsize=9)
    clean_ax(ax, axis="x")

    handles = [mpatches.Patch(color=c, label=lbl) for _, c, lbl in reflines]
    ax.legend(handles=handles, fontsize=7, loc="lower right", framealpha=0.7)

# ── ROW 1: all metrics | missed cancers ─────────────────────────────────────
row1 = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=outer[1], wspace=0.08)
ax_multi = fig.add_subplot(row1[0])
ax_fn = fig.add_subplot(row1[1])

MK = ["auc", "pr_auc", "acc", "sens", "spec", "f1", "mcc"]
MLBL = ["ROC-AUC", "PR-AUC", "Accuracy", "Sensitivity", "Specificity", "F1", "MCC"]

x = np.arange(len(MK))
bw = 0.35

for i, nm in enumerate(names):
    vals = [MODELS[nm][k] for k in MK]
    ax_multi.bar(
        x + (i - 0.5) * bw,
        vals,
        bw,
        color=MODELS[nm]["color"],
        alpha=0.88,
        label=nm.replace("\n", " "),
    )

all_vals = [MODELS[nm][k] for nm in names for k in MK]
ax_multi.set_xticks(x)
ax_multi.set_xticklabels(MLBL, rotation=15, ha="right", fontsize=8)
ax_multi.set_ylim(min(-0.10, min(all_vals) - 0.05), 1.12)
ax_multi.axhline(0.00, color="black", lw=0.8, alpha=0.45)
ax_multi.axhline(0.80, color="#27AE60", ls="--", lw=1, alpha=0.5)
ax_multi.axhline(0.65, color="#F39C12", ls="--", lw=1, alpha=0.5)
ax_multi.set_title("All Metrics Compared", fontsize=10, fontweight="bold")
ax_multi.legend(fontsize=7, loc="upper right")
clean_ax(ax_multi, axis="y")

rank_fn = sorted(names, key=lambda n: MODELS[n]["fn"])
fn_vals = [MODELS[n]["fn"] for n in rank_fn]
fn_cols = [MODELS[n]["color"] for n in rank_fn]

fn_bars = ax_fn.barh(rank_fn, fn_vals, color=fn_cols, height=0.5, edgecolor="white")
ax_fn.invert_yaxis()

for bar, fn, nm in zip(fn_bars, fn_vals, rank_fn):
    n_mal = MODELS[nm]["n_mal"]
    ax_fn.text(
        fn + 0.8,
        bar.get_y() + bar.get_height() / 2,
        f"{fn}  ({fn / n_mal * 100:.1f}%)",
        va="center",
        fontsize=9,
        fontweight="bold" if "New" in nm else "normal",
    )

ax_fn.axvline(
    _b_fn,
    color=MODELS["Old\n(VGG19)"]["color"],
    ls="--",
    lw=1.2,
    alpha=0.8,
    label=f"Old FN={_b_fn}",
)
ax_fn.set_title(
    f"Missed Cancers (FN)\nout of {n_malignant} malignant  ← lower is better",
    fontsize=10,
    fontweight="bold",
)
ax_fn.set_xlabel("False Negatives (missed cancers)", fontsize=9)
ax_fn.legend(fontsize=7)
clean_ax(ax_fn, axis="x")

# ── ROW 2: confusion matrices ───────────────────────────────────────────────
row2 = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=outer[2], wspace=0.18)
cmap_cm = LinearSegmentedColormap.from_list(
    "cm_dashboard",
    ["#1A3A5C", "#2980B9", "#D4E6F1"],
)

for i, nm in enumerate(names):
    d = MODELS[nm]
    cm_arr = np.array([[d["tn"], d["fp"]], [d["fn"], d["tp"]]])
    n = cm_arr.sum()

    ax = fig.add_subplot(row2[i])
    ax.imshow(cm_arr, cmap=cmap_cm, vmin=0, vmax=max(cm_arr.max(), 1))

    for r in range(2):
        for c in range(2):
            val = cm_arr[r, c]
            ax.text(
                c,
                r,
                f"{val}\n{val / n * 100:.1f}%",
                ha="center",
                va="center",
                fontsize=14,
                fontweight="bold",
                color="white" if val > cm_arr.max() * 0.4 else "#1A1A2E",
            )

    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])
    ax.set_xticklabels(["Pred Benign", "Pred Malignant"], fontsize=9)
    ax.set_yticklabels(["True Benign", "True Malignant"], fontsize=9)
    ax.set_title(
        f"{nm.replace(chr(10), ' ')}\n"
        f"AUC={d['auc']:.3f}  Sens={d['sens']:.3f}  FN={d['fn']}",
        fontsize=10,
        fontweight="bold",
        color=status_color(d["auc"]),
        pad=8,
    )

# ── ROW 3: ROC and PR curves ────────────────────────────────────────────────
row3 = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=outer[3], wspace=0.12)
ax_roc = fig.add_subplot(row3[0])
ax_pr = fig.add_subplot(row3[1])

fpr_new, tpr_new, thr_new = roc_curve(y_true_dash, y_prob_dash)
youden_idx = int(np.argmax(tpr_new - fpr_new))

pr_precision, pr_recall, _ = precision_recall_curve(y_true_dash, y_prob_dash)
random_pr = y_true_dash.mean()

b = MODELS["Old\n(VGG19)"]
n = MODELS["New\n(VGG19)"]

# Old raw probabilities are not available from the image,
# so this is an operating-point proxy using the old confusion matrix.
ax_roc.plot(
    [0, 1 - b["spec"], 1],
    [0, b["sens"], 1],
    "--",
    color=b["color"],
    lw=1.5,
    label=f"Old operating point AUC={b['auc']:.4f}",
)
ax_roc.scatter(
    [1 - b["spec"]],
    [b["sens"]],
    color=b["color"],
    s=80,
    zorder=5,
)

ax_roc.plot(
    fpr_new,
    tpr_new,
    "-",
    color=n["color"],
    lw=2.5,
    label=f"New VGG19 AUC={n['auc']:.4f}",
)
ax_roc.scatter(
    [fpr_new[youden_idx]],
    [tpr_new[youden_idx]],
    color=n["color"],
    s=80,
    zorder=5,
    label="Youden point",
)
ax_roc.scatter(
    [1 - n["spec"]],
    [n["sens"]],
    marker="X",
    color=n["color"],
    s=100,
    zorder=6,
    label=f"Chosen thr={n['thr']:.3f}",
)

ax_roc.plot([0, 1], [0, 1], "k--", lw=0.8, alpha=0.5)
ax_roc.axhline(0.80, color="#27AE60", ls=":", lw=0.8, alpha=0.6, label="Sens=0.80")
ax_roc.set_xlabel("False Positive Rate")
ax_roc.set_ylabel("True Positive Rate")
ax_roc.set_title("ROC Curve Comparison", fontsize=11, fontweight="bold")
ax_roc.legend(fontsize=8)
clean_ax(ax_roc)

ax_pr.plot(
    pr_recall,
    pr_precision,
    "-",
    color=n["color"],
    lw=2.5,
    label=f"New VGG19 AP={n['pr_auc']:.4f}",
)
ax_pr.axhline(random_pr, color="gray", ls="--", lw=1, label=f"Random ({random_pr:.2f})")

ax_pr.scatter(
    [b["sens"]],
    [b["prec"]],
    color=b["color"],
    s=80,
    zorder=5,
    label=f"Old Sens={b['sens']:.3f} Prec={b['prec']:.3f}",
)
ax_pr.scatter(
    [n["sens"]],
    [n["prec"]],
    color=n["color"],
    marker="X",
    s=100,
    zorder=6,
    label=f"New Sens={n['sens']:.3f} Prec={n['prec']:.3f}",
)

ax_pr.set_xlabel("Recall")
ax_pr.set_ylabel("Precision")
ax_pr.set_title("Precision-Recall Curve", fontsize=11, fontweight="bold")
ax_pr.legend(fontsize=8)
clean_ax(ax_pr)

# ── ROW 4: scorecard table ─────────────────────────────────────────────────
ax_tbl = fig.add_subplot(outer[4])
ax_tbl.axis("off")

COLS = [
    "Model",
    "AUC",
    "PR-AUC",
    "Acc",
    "Bal-Acc",
    "Sens",
    "Spec",
    "F1",
    "MCC",
    "FN",
    "Miss%",
    "Status",
]

rows_data = []
for nm in names:
    d = MODELS[nm]
    bal_acc = (d["sens"] + d["spec"]) / 2
    rows_data.append([
        nm.replace("\n", " "),
        f"{d['auc']:.4f}",
        f"{d['pr_auc']:.4f}",
        f"{d['acc']:.4f}",
        f"{bal_acc:.4f}",
        f"{d['sens']:.4f}",
        f"{d['spec']:.4f}",
        f"{d['f1']:.4f}",
        f"{d['mcc']:.4f}",
        str(d["fn"]),
        f"{d['fn'] / d['n_mal'] * 100:.1f}%",
        display_status(nm),
    ])

tbl = ax_tbl.table(cellText=rows_data, colLabels=COLS, loc="center", cellLoc="center")
tbl.auto_set_font_size(False)
tbl.set_fontsize(9)
tbl.scale(1.0, 2.2)

# Header
for j in range(len(COLS)):
    tbl[(0, j)].set_facecolor("#1A3A5C")
    tbl[(0, j)].set_text_props(color="white", fontweight="bold")

row_bg = ["#FDEDEC", "#EBF5FB"]
for i, nm in enumerate(names):
    sc = status_color(MODELS[nm]["auc"])
    for j in range(len(COLS)):
        cell = tbl[(i + 1, j)]
        cell.set_facecolor(row_bg[i])
        if j == 1:
            cell.set_text_props(fontweight="bold")
        if j == len(COLS) - 1:
            cell.set_text_props(color=sc, fontweight="bold")

# Highlight winners
higher_is_better = {1, 2, 3, 4, 5, 6, 7, 8}
lower_is_better = {9, 10}

for col_idx in range(1, len(COLS) - 1):
    raw = []
    for r in range(len(names)):
        txt = tbl[(r + 1, col_idx)].get_text().get_text().replace("%", "")
        raw.append(float(txt))

    if col_idx in higher_is_better:
        best_val = max(raw)
    elif col_idx in lower_is_better:
        best_val = min(raw)
    else:
        continue

    for r, val in enumerate(raw):
        if abs(val - best_val) < 1e-9:
            tbl[(r + 1, col_idx)].set_facecolor("#D5F5E3")

ax_tbl.set_title(
    "Complete Scorecard  (Old VGG19 → New VGG19)",
    fontsize=11,
    fontweight="bold",
    pad=12,
    y=1.0,
)

# ── Save ────────────────────────────────────────────────────────────────────
save_path = Path(SAVE_DIR) / "vgg19_old_vs_new_comparison_dashboard.png"
plt.savefig(save_path, dpi=150, bbox_inches="tight", facecolor="#F8F9FA")
plt.show()

print(f"✅ VGG19 comparison dashboard saved → {save_path}")
# Out:
# ✅ VGG19 comparison dashboard saved → /content/drive/MyDrive/THESIS/cbis-ddsm/model_output_common_n502_fixed_xai/vgg19_common_split_n502_fixed_xai/vgg19_old_vs_new_comparison_dashboard.png
